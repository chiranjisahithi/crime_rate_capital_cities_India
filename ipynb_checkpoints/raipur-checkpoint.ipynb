# %%
import pandas as pd
import numpy as np
from bokeh.plotting import output_file, show, figure, ColumnDataSource
import matplotlib.pyplot as plt 
from bokeh.palettes import Category20c
from bokeh.transform import cumsum
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
df=pd.read_csv("https://code.swecha.org/CivicTech/analysis-on-survillance-in-indian-cities/-/raw/Challengers/RAIPUR-1.csv",encoding='cp1252')
pd.set_option('display.max_rows',None)
df
# Out:
#     year  RESIDENTIAL_PREMISESRobbery  RESIDENTIAL_PREMISESBurglary  \
# 0   2010                           60                          2707
# 1   2011                           39                          2814
# 2   2012                           59                          2855
# 3   2013                           59                          3098
# 4   2014                           74                          2828
# 5   2015                           42                          2853
# 6   2016                           58                          3225
# 7   2017                           47                          3121
# 8   2018                           58                          2800
# 9   2019                           30                          2602
# 10  2020                           27                          1998
#
#     RESIDENTIAL_PREMISESTheft  HIGHWAYSRobbery  HIGHWAYSTheft  RAILWAYSTheft  \
# 0                        1121               51             62            191
# 1                        1116               19             47            297
# 2                        1426               33             16            249
# 3                        1401               42            144            275
# 4                        1343               70             55            237
# 5                        1254               61             26            201
# 6                        1404              101              5            210
# 7                        1187              115             33            272
# 8                        1517               62            117            218
# 9                        1392               36             46            205
# 10                       1386               23             35            210
#
#     BANKSDacoity  BANKSRobbery  BANKSBurglary  BANKSTheft  Total  Cameras  \
# 0             11            11              6         254   4474    51442
# 1              0             1              7           6   4346    51370
# 2              1             1              3          79   4722    54958
# 3              3             3             26           7   5058    57218
# 4              0             4             10           7   4628    58598
# 5              1            10              6           7   4461    56870
# 6              0             8             12           8   5031    58200
# 7              1             6              5          14   4801    59000
# 8              0             0              7          10   4789    59460
# 9              0             0             14          13   4338    61475
# 10             0             0             11           7   3697    65145
#
#     Crime_index
# 0         807.5
# 1         794.5
# 2         765.3
# 3         721.9
# 4         641.5
# 5         593.7
# 6         547.6
# 7         479.5
# 8         416.8
# 9         391.4
# 10        355.5

# %%
output_file("CAMERARAI.html")
year=[]
cameras=[]
l1=[]
for i in range(0,11):
    cameras.append(df.Cameras[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CAMERAS IN RAIPUR",y_axis_label="NUMBER OF CAMERAS",x_axis_label="YEAR")
p.vbar(x=year,top=cameras,width=0.6,color="orange")
show(p)

# %%
output_file("CRIMERAI.html")
year=[]
crime=[]
l1=[]
for i in range(0,11):
    crime.append(df.Crime_index[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CRIME IN RAIPUR",y_axis_label="CRIME RATE",x_axis_label="YEAR")
p.vbar(x=year,top=crime,width=0.6,color="blue")
show(p)

# %%
from math import pi
import pandas as pd
from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.plotting import output_notebook
output_notebook()
output_file("raipie.html")
year=[]
camera=[]
for i in range(0,11):
    year.append(str(df.year[i]))
    camera.append(df.Cameras[i])

x=dict(zip(year,camera))

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'year'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@year: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='year', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1724">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ce52ded8-ba4f-4497-995a-cefe877cf110" data-root-id="1725"></div>

# %%
source=ColumnDataSource(df)
p=figure(plot_width=400,plot_height=400,title='SURVEILLANCE',x_axis_label='YEAR',y_axis_label='Number of Cameras')
output_file("Rai.html")
p.line(x="year", y="Cameras", source=source,line_width=4,color="blue")
p.square(x="year" , y="Cameras", source=source,color="yellow",size=6)
hover = HoverTool()
hover.tooltips=[('Year','@year'),('Number of Cameras','@Cameras'),('Number of residential robbery','@RESIDENTIA_ PREMISESRobbery'),('Number of residential Burglary','@RESIDENTIAL_PREMISESBurglary'),('Number residential of Theft','@RESIDENTIAL_PREMISESTheft'),('Highway Robbery','@HIGHWAYSRobbery'),('Highway theft','@HIGHWAYSTheft'),('Railway theft','@RAILWAYSTheft'),('Bank dacoity','@BANKSDacoity'),('Bank robbey','@BANKSRobbery'),('Bank burglary','@BANKSBurglary'),('Bank Theft','@BANKSTheft'),('Crime Index','@Crime_index')]
p.add_tools(hover)
show(p)
# Out:
#   <div class="bk-root" id="4f3fee20-e035-4e6c-a844-73ecd796ed50" data-root-id="2935"></div>

# %%
from bokeh.plotting import figure,output_file,show

output_file("RAISCA.html")
p=figure(plot_width=1100,plot_height=500,title="CRIME IN GOA",y_axis_label="values",x_axis_label="year")

p.circle(df["year"],df["RESIDENTIAL_PREMISESRobbery"],size=12,line_color='green',fill_color='orange',fill_alpha=1,legend_label="RESIDENTIAL ROBBERY")

p.square(df["year"],df["RESIDENTIAL_PREMISESTheft"],size=10,line_color='green',fill_color='yellow',fill_alpha=1,legend_label="RESIDENTIAL THEFT")

p.triangle(df["year"],df["HIGHWAYSRobbery"],size=14,line_color='cyan',fill_color='blue',fill_alpha=1,legend_label="HIGHWAY ROBBERY")


p.diamond(df["year"],df["HIGHWAYSTheft"],size=15,line_color='black',fill_color='red',fill_alpha=1,legend_label="THEFT IN HIGHWAY")

p.hex(df["year"],df["Cameras"],size=15,line_color='yellow',fill_color='violet',fill_alpha=1,legend_label="TOTAL CAMERAS")
p.dot(df["year"],df["Crime_index"],size=25,line_color='red',fill_color='black',fill_alpha=1,legend_label="CRIME RATE")

show(p)
# Out:
#   <div class="bk-root" id="2cf3bc92-4601-4d47-ab66-cecf0af05445" data-root-id="2395"></div>
