# %%
import pandas as pd
import numpy as np
from bokeh.plotting import output_file, show, figure, ColumnDataSource
import matplotlib.pyplot as plt 
from bokeh.palettes import Category20c
from bokeh.transform import cumsum
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
df=pd.read_csv("https://code.swecha.org/CivicTech/analysis-on-survillance-in-indian-cities/-/raw/Challengers/LUCKNOW-1.csv",encoding='cp1252')
pd.set_option('display.max_rows',None)
df
# Out:
#     year  RESIDENTIAL_PREMISESRobbery  RESIDENTIAL_PREMISESBurglary  \
# 0   2010                          504                          6693
# 1   2011                          381                          4480
# 2   2012                          215                          2702
# 3   2013                          294                          3878
# 4   2014                          160                          3846
# 5   2015                          160                          3138
# 6   2016                          160                          3676
# 7   2017                          160                          3747
# 8   2018                          160                          5623
# 9   2019                          160                          3080
# 10  2020                          160                          3340
#
#     RESIDENTIAL_PREMISESTheft  HIGHWAYSRobbery  HIGHWAYSTheft  RAILWAYSTheft  \
# 0                        6383             2015           6121           3141
# 1                        6588             1322           3096           2845
# 2                        3892              957           2634           2487
# 3                        6526             1312           4216           1970
# 4                        3661             1431           4256            480
# 5                        4869              864           6037            761
# 6                        3166              791          10223           1521
# 7                        3945              891          11312           1267
# 8                        9619               88            506            920
# 9                        3100               84           1188            296
# 10                        392              279           1353            320
#
#     BANKSDacoity  BANKSRobbery  BANKBurglary  BANKSTheft  Total  Cameras  \
# 0              0            13             2           1  24873     3005
# 1              3            17             6           4  18742     5042
# 2              4            10             0           0  12901     5489
# 3              2             6             0           0  18204     5540
# 4              1             1            28           7  13871     6054
# 5              3             6             0           0  15838     6200
# 6              3             5             1           0  19546     6354
# 7              1             8             1           0  21332     6500
# 8              2             0            20          36  16974     7240
# 9              2             2            13           4   7929     9000
# 10             1             3            13           5   5866    10800
#
#     Crime_index
# 0        300.40
# 1        288.10
# 2        284.40
# 3        275.00
# 4        260.40
# 5        255.50
# 6        240.50
# 7        237.20
# 8        193.30
# 9         45.90
# 10        34.08

# %%
output_file("CAMERALUCK.html")
year=[]
cameras=[]
l1=[]
for i in range(0,11):
    cameras.append(df.Cameras[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CAMERAS IN LUCKNOW",y_axis_label="NUMBER OF CAMERAS",x_axis_label="YEAR")
p.vbar(x=year,top=cameras,width=0.6,color="pink")
show(p)

# %%
output_file("CRIMELUCK.html")
year=[]
crime=[]
l1=[]
for i in range(0,11):
    crime.append(df.Crime_index[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CRIME IN LUCKNOW",y_axis_label="CRIME RATE",x_axis_label="YEAR")
p.vbar(x=year,top=crime,width=0.6,color="blue")
show(p)

# %%
from math import pi
import pandas as pd
from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.plotting import output_notebook
output_notebook()
output_file("luckpie.html")
year=[]
camera=[]
for i in range(0,11):
    year.append(str(df.year[i]))
    camera.append(df.Cameras[i])

x=dict(zip(year,camera))

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'year'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@year: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='year', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1269">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1c4ff738-8754-4295-ac03-ee3e7154581e" data-root-id="1270"></div>

# %%
source=ColumnDataSource(df)
p=figure(plot_width=400,plot_height=400,title='SURVEILLANCE',x_axis_label='YEAR',y_axis_label='Number of Cameras')
output_file("LUCK1.html")
p.line(x="year", y="Cameras", source=source,line_width=4,color="green")
p.square(x="year" , y="Cameras", source=source,color="pink",size=6)
hover = HoverTool()
hover.tooltips=[('Year','@year'),('Number of Cameras','@Cameras'),('Number of residential robbery','@RESIDENTIAL_PREMISESRobbery'),('Number of residential Burglary','@RESIDENTIAL_PREMISESBurglary'),('Number residential of Theft','@RESIDENTIAL_PREMISESTheft'),('Highway Robbery','@HIGHWAYSRobbery'),('Highway theft','@HIGHWAYSTheft'),('Railway theft','@RAILWAYSTheft'),('Bank dacoity','@BANKSDacoity'),('Bank robbey','@BANKSRobbery'),('Bank burglary','@BANKBurglary'),('Bank Theft','@BANKSTheft'),('Crime Index','@Crime_index')]
p.add_tools(hover)
show(p)
# Out:
#   <div class="bk-root" id="689c1f02-638f-4bfd-92ea-3ee4e0c4e194" data-root-id="1651"></div>

# %%
from bokeh.plotting import figure,output_file,show

output_file("LUCKSCA.html")
p=figure(plot_width=1100,plot_height=500,title="CRIME IN HYDERABAD",y_axis_label="values",x_axis_label="year")

p.circle(df["year"],df["RESIDENTIAL_PREMISESRobbery"],size=12,line_color='green',fill_color='orange',fill_alpha=1,legend_label="RESIDENTIAL ROBBERY")

p.square(df["year"],df["RESIDENTIAL_PREMISESTheft"],size=10,line_color='green',fill_color='yellow',fill_alpha=1,legend_label="RESIDENTIAL THEFT")

p.triangle(df["year"],df["HIGHWAYSRobbery"],size=14,line_color='cyan',fill_color='blue',fill_alpha=1,legend_label="HIGHWAY ROBBERY")


p.diamond(df["year"],df["HIGHWAYSTheft"],size=15,line_color='black',fill_color='red',fill_alpha=1,legend_label="THEFT IN HIGHWAY")

p.hex(df["year"],df["Cameras"],size=15,line_color='yellow',fill_color='violet',fill_alpha=1,legend_label="TOTAL CAMERAS")
p.dot(df["year"],df["Crime_index"],size=25,line_color='red',fill_color='black',fill_alpha=1,legend_label="CRIME RATE")

show(p)
# Out:
#   <div class="bk-root" id="3aee456d-aa63-4dcb-be87-847d08699d94" data-root-id="1872"></div>
