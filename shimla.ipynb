# %%
import pandas as pd
import numpy as np
from bokeh.plotting import output_file, show, figure, ColumnDataSource
import matplotlib.pyplot as plt 
from bokeh.palettes import Category20c
from bokeh.transform import cumsum
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
df=pd.read_csv("https://code.swecha.org/CivicTech/analysis-on-survillance-in-indian-cities/-/raw/Challengers/SHIMLA-1.csv",encoding='cp1252')
pd.set_option('display.max_rows',None)
df
# Out:
#     year  RESIDENTIA_ PREMISESRobbery  RESIDENTIAL_PREMISESBurglary  \
# 0   2010                            2                           328
# 1   2011                            3                           308
# 2   2012                            1                           328
# 3   2013                            6                           332
# 4   2014                            7                           308
# 5   2015                            2                           370
# 6   2016                            3                           422
# 7   2017                            1                           404
# 8   2018                            1                           367
# 9   2019                            2                           374
# 10  2020                            1                           218
#
#     RESIDENTIAL_PREMISESTheft  HIGHWAYSRobbery  HIGHWAYSTheft  RAILWAYSTheft  \
# 0                          55                2             10              1
# 1                          71                2             10              0
# 2                          62                3             51              0
# 3                          47                2             26              0
# 4                         126                4             26              0
# 5                          84                4             13              0
# 6                          93                6             43              0
# 7                         100                5             34              0
# 8                         153                1             25              2
# 9                         157                0             38              3
# 10                        115                1             28              3
#
#     BANKSDacoity  BANKSRobbery  BANKSBurglary  BANKSTheft  Total  Cameras  \
# 0              0             1             75           1    475    13976
# 1              0             2              6           1    403    13315
# 2              2             1              8           0    456    13049
# 3              0             1             14           0    428    14312
# 4              0             0             15           0    486    14517
# 5              0             0             12           1    486    14987
# 6              0             0              5           1    573    15147
# 7              1             0             12           0    557    15427
# 8              0             3             17           0    569    15859
# 9              0             0              4           4    582    16017
# 10             0             0              4           4    374    16750
#
#     Crime_index
# 0         400.3
# 1         375.4
# 2         369.5
# 3         335.2
# 4         316.9
# 5         282.7
# 6         253.9
# 7         195.2
# 8         152.0
# 9          96.4
# 10         53.2

# %%
output_file("CAMERASIM.html")
year=[]
cameras=[]
l1=[]
for i in range(0,11):
    cameras.append(df.Cameras[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CAMERAS IN SHIMLA",y_axis_label="NUMBER OF CAMERAS",x_axis_label="YEAR")
p.vbar(x=year,top=cameras,width=0.6,color="orange")
show(p)

# %%
output_file("CRIMESIM.html")
year=[]
crime=[]
l1=[]
for i in range(0,11):
    crime.append(df.Crime_index[i])
    l1.append(df.year[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CRIME IN SHIMLA",y_axis_label="CRIME RATE",x_axis_label="YEAR")
p.vbar(x=year,top=crime,width=0.6,color="blue")
show(p)

# %%
from math import pi
import pandas as pd
from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.plotting import output_notebook
output_notebook()
output_file("simpie.html")
year=[]
camera=[]
for i in range(0,11):
    year.append(str(df.year[i]))
    camera.append(df.Cameras[i])

x=dict(zip(year,camera))

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'year'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@year: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='year', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1269">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f509fe4c-2955-4d73-8414-33aed27e180f" data-root-id="1270"></div>

# %%
source=ColumnDataSource(df)
p=figure(plot_width=400,plot_height=400,title='SURVEILLANCE',x_axis_label='YEAR',y_axis_label='Number of Cameras')
output_file("SIM.html")
p.line(x="year", y="Cameras", source=source,line_width=4,color="blue")
p.square(x="year" , y="Cameras", source=source,color="yellow",size=6)
hover = HoverTool()
hover.tooltips=[('Year','@year'),('Number of Cameras','@Cameras'),('Number of residential robbery','@RESIDENTIAL_PREMISESRobbery'),('Number of residential Burglary','@RESIDENTIAL_PREMISESBurglary'),('Number residential of Theft','@RESIDENTIAL_PREMISESTheft'),('Highway Robbery','@HIGHWAYSRobbery'),('Highway theft','@HIGHWAYSTheft'),('Railway theft','@RAILWAYSTheft'),('Bank dacoity','@BANKSDacoity'),('Bank robbey','@BANKSRobbery'),('Bank burglary','@BANKSBurglary'),('Bank Theft','@BANKSTheft'),('Crime Index','@Crime_index')]
p.add_tools(hover)
show(p)
# Out:
#   <div class="bk-root" id="f7349da9-605c-4698-84ff-5ec186ee9328" data-root-id="3465"></div>

# %%
from bokeh.plotting import figure,output_file,show

output_file("SIMSCA.html")
p=figure(plot_width=1100,plot_height=500,title="CRIME IN GOA",y_axis_label="values",x_axis_label="year")

p.circle(df["year"],df["RAILWAYSTheft"],size=12,line_color='green',fill_color='orange',fill_alpha=1,legend_label="RESIDENTIAL ROBBERY")

p.square(df["year"],df["RESIDENTIAL_PREMISESTheft"],size=10,line_color='green',fill_color='yellow',fill_alpha=1,legend_label="RESIDENTIAL THEFT")

p.triangle(df["year"],df["HIGHWAYSRobbery"],size=14,line_color='cyan',fill_color='blue',fill_alpha=1,legend_label="HIGHWAY ROBBERY")


p.diamond(df["year"],df["HIGHWAYSTheft"],size=15,line_color='black',fill_color='red',fill_alpha=1,legend_label="THEFT IN HIGHWAY")

p.hex(df["year"],df["Cameras"],size=15,line_color='yellow',fill_color='violet',fill_alpha=1,legend_label="TOTAL CAMERAS")
p.dot(df["year"],df["Crime_index"],size=25,line_color='red',fill_color='black',fill_alpha=1,legend_label="CRIME RATE")

show(p)
# Out:
#   <div class="bk-root" id="65686215-080b-407e-822b-ae76d1764676" data-root-id="2898"></div>
