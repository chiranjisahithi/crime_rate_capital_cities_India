# %%
import pandas as pd
import numpy as np
from bokeh.plotting import output_file, show, figure, ColumnDataSource 
import matplotlib.pyplot as plt 
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.palettes import Category20c
from bokeh.transform import cumsum

# %%
df=pd.read_csv("https://code.swecha.org/CivicTech/analysis-on-survillance-in-indian-cities/-/raw/Challengers/delhi1.csv")
pd.set_option('display.max_rows',None)
df
# Out:
#     Year  TOTAL_DACOITY  TOTAL_ROBBERY  TOTAL_BURGLARY  TOTAL_THEFT  \
# 0   2010          13668             48             624         3029
# 1   2011             47            502            2360        16625
# 2   2012             28            441            1898        15544
# 3   2013             30            461            1875        18994
# 4   2014             14            541            1950        17498
# 5   2015             34            557            2055        17037
# 6   2016             24            541            1926        18867
# 7   2017             36            515            1733        21731
# 8   2018            599           1502           23088        15436
# 9   2019            562           1419           22899           33
# 10  2020            608           1715           22032           28
#
#     AGAINST_WOMEN  TOTALCASES  TOTAL_CAMERAS  CRIME_INDEX
# 0          470556      489925          24357       809.60
# ...

# %%
from math import pi
import pandas as pd
from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.plotting import output_notebook
output_notebook()
output_file("DELHIPIE.html")
year=[]
camera=[]
for i in range(0,10):
    year.append(str(df.Year[i]))
    camera.append(df.TOTAL_CAMERAS[i])

x=dict(zip(year,camera))

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'year'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@year: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='year', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="92c8dde5-78d7-4ab6-b4ab-be8c15a701c8" data-root-id="1002"></div>

# %%
output_file("DELHICRIMEV.html")
year=[]
crime=[]
l1=[]
dacoity=[]
for i in range(0,11):
    l1.append(df.Year[i])
    crime.append(df.CRIME_INDEX[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CAMERAS IN DELHI",y_axis_label="CRIME RATE ",x_axis_label="YEAR")
p.vbar(x=year,top=crime,width=0.6,color="green")
show(p)

# %%
output_file("DELHIV.html")
year=[]
crime=[]
l1=[]
for i in range(0,11):
    l1.append(df.Year[i])
    crime.append(df.CRIME_INDEX[i])
for i in l1 :
    year.append(str(i))
p=figure(x_range=year,title="CAMERAS IN DELHI",y_axis_label="CRIME RATE ",x_axis_label="YEAR")
p.vbar(x=year,top=crime,width=0.6,color="green")
show(p)

# %%
source=ColumnDataSource(df)
p=figure(plot_width=400,plot_height=400,title='SURVEILLANCE',x_axis_label='YEAR',y_axis_label='Number of Cameras')
output_file("delhi2.html")
p.line(x="Year", y="TOTAL_CAMERAS", source=source,line_width=4,color="red")
p.square(x="Year" , y="TOTAL_CAMERAS", source=source,color="yellow",size=6)
hover = HoverTool()
hover.tooltips=[('Year','@Year'),('Number of Cameras','@TOTAL_CAMERAS'),('Number of dacoity','@TOTAL_DACOITY'),('Number of Burglary','@TOTAL_BURGLARY'),('Number of Theft','@TOTAL_THEFT'),('Against Women','@AGAINST_WOMEN')]
p.add_tools(hover)
show(p)

# %%
source=ColumnDataSource(df)
p=figure(plot_width=400,plot_height=400,title='SURVEILLANCE',x_axis_label='NUMBER OF CAMERAS',y_axis_label='CRIME RATE')
output_file("delhi3.html")
p.line(x="TOTAL_CAMERAS", y="CRIME_INDEX", source=source,line_width=4,color="green")
p.square(x="TOTAL_CAMERAS" , y="CRIME_INDEX", source=source,color="yellow")
hover = HoverTool()
hover.tooltips=[('TOTAL_CAMERAS','@TOTAL_CAMERAS'),('CRIME INDEX','@CRIME_INDEX')]
p.add_tools(hover)
show(p)

# %%
output_file("DELHIsam.html")
df.plot.bar("TOTAL_CAMERAS","CRIME_INDEX",color="cyan")
show(p)

# %%
output_file("delhisam1.html")
df.plot.line("Year","TOTAL_CAMERAS",color="firebrick")
show(p)

# %%
from math import pi

import pandas as pd

from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.plotting import output_notebook
output_notebook()
output_file("DELHIPIE.html")
crime=[]
camera=[]
for i in range(0,10):
    crime.append(str(df.CRIME_INDEX[i]))
    camera.append(df.TOTAL_CAMERAS[i])

x=dict(zip(crime,camera))

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'camera'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@camera: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='camera', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)

# %%
from bokeh.plotting import figure,output_file,show

output_file("DELHISCA.html")
p=figure(plot_width=1100,plot_height=500,title="CRIME IN DELHI",y_axis_label="values",x_axis_label="year")

p.circle(df["Year"],df["TOTAL_ROBBERY"],size=12,line_color='green',fill_color='orange',fill_alpha=1,legend_label="Total Robbery")

p.square(df["Year"],df["TOTAL_BURGLARY"],size=10,line_color='green',fill_color='yellow',fill_alpha=1,legend_label="Total Burglary")

p.triangle(df["Year"],df["TOTAL_THEFT"],size=14,line_color='cyan',fill_color='blue',fill_alpha=1,legend_label="Total theft")


p.diamond(df["Year"],df["AGAINST_WOMEN"],size=15,line_color='black',fill_color='red',fill_alpha=1,legend_label="Aganist women")

p.hex(df["Year"],df["TOTAL_CASES"],size=15,line_color='yellow',fill_color='violet',fill_alpha=1,legend_label="Total cases")
p.dot(df["Year"],df["TOTAL_CAMERAS"],size=25,line_color='red',fill_color='black',fill_alpha=1,legend_label="Total cameras")


show(p)
